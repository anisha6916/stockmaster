# %%
# !pip install --user yfinance

import yfinance as yf
import matplotlib.pyplot as plt

# %%
# Define the ticker symbol
# ticker_symbol = "MANH"
ticker_symbol = input ("Enter the ticker: ")

# Fetch the stock data
stock_data = yf.download(ticker_symbol)

# Display the stock data
stock_data["Close"].plot()
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title(f"{ticker_symbol} Stock Price")
plt.show()
# Out:
# Enter the ticker: NKE
# [*********************100%***********************]  1 of 1 completed

# %%
# !pip install --user pandas

import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
api_key = "48DLTGVMBYJ62MHH"

# ticker_symbol = "MANH"
company_name = "Manhattan Associates"

income_statement_url = f"https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={ticker_symbol}&apikey={api_key}"
income_statement_data = requests.get(income_statement_url).json()

net_income = float(income_statement_data["annualReports"][0]["netIncome"])
print("net_income: ", net_income)

balance_sheet_url = f"https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol={ticker_symbol}&apikey={api_key}"
balance_sheet_data = requests.get(balance_sheet_url).json()

total_assets = float(balance_sheet_data["annualReports"][0]["totalAssets"])

roic = net_income / total_assets
print("roic: ", roic)

# plt.figure(figsize=(8, 6))
# plt.bar(company_name, roic)
# plt.ylabel("ROIC")
# plt.title(f"Return on Invested Capital (ROIC) - {company_name}")
# plt.grid(True)
# plt.show()
# Out:
# net_income:  6046000000.0
# roic:  0.14994667790977406

# %%
api_key = "48DLTGVMBYJ62MHH"

# ticker_symbol = "MANH"
company_name = "Manhattan Associates"

yearly_netincomes = []
yearly_assets = []

income_statement_url = f"https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={ticker_symbol}&apikey={api_key}"
income_statement_data = requests.get(income_statement_url).json()
print(income_statement_data)

net_income = float(income_statement_data["annualReports"][0]["netIncome"])
print("net_income: ", net_income)

for report in income_statement_data["annualReports"]:
    ni = float(report["netIncome"])
    yearly_netincomes.append(ni)
    print(report['fiscalDateEnding'], " : ", ni)
    

balance_sheet_url = f"https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol={ticker_symbol}&apikey={api_key}"
balance_sheet_data = requests.get(balance_sheet_url).json()
# print(balance_sheet_data)

total_assets = float(balance_sheet_data["annualReports"][0]["totalAssets"])
print("total_assets: ", total_assets)

for report in balance_sheet_data["annualReports"]:
    ta = float(report["totalAssets"])
    yearly_assets.append(ta)
    print(report['fiscalDateEnding'], " : ", ta)

roic = net_income / total_assets
print("roic: ", roic)

yearly_roics = []
for i in range(len(yearly_netincomes)):
    roic = yearly_netincomes[i] / yearly_assets[i]
    print(roic)
    yearly_roics.append(roic)

# plt.figure(figsize=(8, 6))
# plt.bar(company_name, roic)
# plt.ylabel("ROIC")
# plt.title(f"Return on Invested Capital (ROIC) - {company_name}")
# plt.grid(True)
# plt.show()
# Out:
# {'symbol': 'NKE', 'annualReports': [{'fiscalDateEnding': '2022-05-31', 'reportedCurrency': 'USD', 'grossProfit': '21479000000', 'totalRevenue': '46736000000', 'costOfRevenue': '40035000000', 'costofGoodsAndServicesSold': '25231000000', 'operatingIncome': '6675000000', 'sellingGeneralAndAdministrative': '14804000000', 'researchAndDevelopment': 'None', 'operatingExpenses': '14804000000', 'investmentIncomeNet': 'None', 'netInterestIncome': '-205000000', 'interestIncome': '205000000', 'interestExpense': '205000000', 'nonInterestIncome': '46736000000', 'otherNonOperatingIncome': '181000000', 'depreciation': '717000000', 'depreciationAndAmortization': '840000000', 'incomeBeforeTax': '6651000000', 'incomeTaxExpense': '605000000', 'interestAndDebtExpense': 'None', 'netIncomeFromContinuingOperations': '6046000000', 'comprehensiveIncomeNetOfTax': '6744000000', 'ebit': '6675000000', 'ebitda': '6675000000', 'netIncome': '6046000000'}, {'fiscalDateEnding': '2021-05-31', 'reportedCurrency': 'USD',
# ...

# %%
import pandas as pd

# !pip install pandas xlsxwriter

json_data = [
    {
        "Name": "John",
        "Age": 30,
        "City": "New York"
    },
    {
        "Name": "Alice",
        "Age": 25,
        "City": "London"
    },
    {
        "Name": "Bob",
        "Age": 35,
        "City": "Paris"
    }
]

df = pd.DataFrame(json_data)

writer = pd.ExcelWriter('data.xlsx', engine='xlsxwriter')

df.to_excel(writer, sheet_name='Sheet1', index=False)

writer.save()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# quarterly_report_data = [{'fiscalDateEnding': '2023-03-31', 'reportedCurrency': 'USD', 'totalAssets': '530843000', 'totalCurrentAssets': '371504000', 'cashAndCashEquivalentsAtCarryingValue': '181595000', 'cashAndShortTermInvestments': '181595000', 'inventory': 'None', 'currentNetReceivables': '160568000', 'totalNonCurrentAssets': '159339000', 'propertyPlantEquipment': '12049000', 'accumulatedDepreciationAmortizationPPE': 'None', 'intangibleAssets': '62233000', 'intangibleAssetsExcludingGoodwill': 'None', 'goodwill': '62233000', 'investments': '0', 'longTermInvestments': 'None', 'shortTermInvestments': 'None', 'otherCurrentAssets': '29341000', 'otherNonCurrentAssets': '28341000', 'totalLiabilities': '349771000', 'totalCurrentLiabilities': '322753000', 'currentAccountsPayable': '25357000', 'deferredRevenue': '216312000', 'currentDebt': 'None', 'shortTermDebt': 'None', 'totalNonCurrentLiabilities': '27018000', 'capitalLeaseObligations': '13044000', 'longTermDebt': 'None', 'currentLongTermDebt': 'None', 'longTermDebtNoncurrent': 'None', 'shortLongTermDebtTotal': '13044000', 'otherCurrentLiabilities': '81084000', 'otherNonCurrentLiabilities': '13974000', 'totalShareholderEquity': '181072000', 'treasuryStock': 'None', 'retainedEarnings': '207176000', 'commonStock': '620000', 'commonStockSharesOutstanding': '62026840'}, {'fiscalDateEnding': '2022-12-31', 'reportedCurrency': 'USD', 'totalAssets': '570178000', 'totalCurrentAssets': '415375000', 'cashAndCashEquivalentsAtCarryingValue': '225463000', 'cashAndShortTermInvestments': '225463000', 'inventory': 'None', 'currentNetReceivables': '167414000', 'totalNonCurrentAssets': '154773000', 'propertyPlantEquipment': '12803000', 'accumulatedDepreciationAmortizationPPE': '54859000', 'intangibleAssets': '62200000', 'intangibleAssetsExcludingGoodwill': 'None', 'goodwill': '62230000', 'investments': '0', 'longTermInvestments': '0', 'shortTermInvestments': 'None', 'otherCurrentAssets': '3614000', 'otherNonCurrentAssets': '24770000', 'totalLiabilities': '343378000', 'totalCurrentLiabilities': '315595000', 'currentAccountsPayable': '25701000', 'deferredRevenue': '208807000', 'currentDebt': 'None', 'shortTermDebt': 'None', 'totalNonCurrentLiabilities': '27783000', 'capitalLeaseObligations': '14065000', 'longTermDebt': 'None', 'currentLongTermDebt': 'None', 'longTermDebtNoncurrent': 'None', 'shortLongTermDebtTotal': '14065000', 'otherCurrentLiabilities': '81087000', 'otherNonCurrentLiabilities': '13718000', 'totalShareholderEquity': '226800000', 'treasuryStock': 'None', 'retainedEarnings': '253711000', 'commonStock': '621000', 'commonStockSharesOutstanding': '62191570'}, {'fiscalDateEnding': '2022-09-30', 'reportedCurrency': 'USD', 'totalAssets': '514719000', 'totalCurrentAssets': '366695000', 'cashAndCashEquivalentsAtCarryingValue': '197055000', 'cashAndShortTermInvestments': '197055000', 'inventory': 'None', 'currentNetReceivables': '143504000', 'totalNonCurrentAssets': '148024000', 'propertyPlantEquipment': '12265000', 'accumulatedDepreciationAmortizationPPE': 'None', 'intangibleAssets': '
 'longTermDebt': 'None', 'currentLongTermDebt': 'None', 'longTermDebtNoncurrent': 'None', 'shortLongTermDebtTotal': 'None', 'otherCurrentLiabilities': '45189000', 'otherNonCurrentLiabilities': '14686000', 'totalShareholderEquity': '147147000', 'treasuryStock': 'None', 'retainedEarnings': '163359000', 'commonStock': '649000', 'commonStockSharesOutstanding': '64860419'}, {'fiscalDateEnding': '2018-09-30', 'reportedCurrency': 'USD', 'totalAssets': '291008000', 'totalCurrentAssets': '203155000', 'cashAndCashEquivalentsAtCarryingValue': '89749000', 'cashAndShortTermInvestments': '93897000', 'inventory': 'None', 'currentNetReceivables': '92966000', 'totalNonCurrentAssets': '86429000', 'propertyPlantEquipment': '14501000', 'accumulatedDepreciationAmortizationPPE': 'None', 'intangibleAssets': '62243000', 'intangibleAssetsExcludingGoodwill': '62243000', 'goodwill': '62243000', 'investments': '0', 'longTermInvestments': '0', 'shortTermInvestments': '4148000', 'otherCurrentAssets': '16292000', 'otherNonCurrentAssets': '9685000', 'totalLiabilities': '151330000', 'totalCurrentLiabilities': '136606000', 'currentAccountsPayable': '14273000', 'deferredRevenue': 'None', 'currentDebt': 'None', 'shortTermDebt': 'None', 'totalNonCurrentLiabilities': '14724000', 'capitalLeaseObligations': 'None', 'longTermDebt': 'None', 'currentLongTermDebt': 'None', 'longTermDebtNoncurrent': 'None', 'shortLongTermDebtTotal': 'None', 'otherCurrentLiabilities': '39313000', 'otherNonCurrentLiabilities': '14724000', 'totalShareholderEquity': '139678000', 'treasuryStock': 'None', 'retainedEarnings': '156912000', 'commonStock': '654000', 'commonStockSharesOutstanding': '65378469'}, {'fiscalDateEnding': '2018-06-30', 'reportedCurrency': 'USD', 'totalAssets': '292495000', 'totalCurrentAssets': '204730000', 'cashAndCashEquivalentsAtCarryingValue': '79034000', 'cashAndShortTermInvestments': '83426000', 'inventory': 'None', 'currentNetReceivables': '99112000', 'totalNonCurrentAssets': '87159000', 'propertyPlantEquipment': '15323000', 'accumulatedDepreciationAmortizationPPE': 'None', 'intangibleAssets': '62244000', 'intangibleAssetsExcludingGoodwill': '62244000', 'goodwill': '62244000', 'investments': '0', 'longTermInvestments': '0', 'shortTermInvestments': '4392000', 'otherCurrentAssets': '22192000', 'otherNonCurrentAssets': '9592000', 'totalLiabilities': '163253000', 'totalCurrentLiabilities': '148027000', 'currentAccountsPayable': '21192000', 'deferredRevenue': 'None', 'currentDebt': 'None', 'shortTermDebt': 'None', 'totalNonCurrentLiabilities': '15226000', 'capitalLeaseObligations': 'None', 'longTermDebt': 'None', 'currentLongTermDebt': 'None', 'longTermDebtNoncurrent': 'None', 'shortLongTermDebtTotal': 'None', 'otherCurrentLiabilities': '36422000', 'otherNonCurrentLiabilities': '15226000', 'totalShareholderEquity': '129242000', 'treasuryStock': 'None', 'retainedEarnings': '143994000', 'commonStock': '658000', 'commonStockSharesOutstanding': '65759735'}]
# FROM BALANCE SHEET:
quarterly_report_data = balance_sheet_data['quarterlyReports']
annual_report_data = balance_sheet_data['annualReports']

df_q = pd.DataFrame(quarterly_report_data)
df_a = pd.DataFrame(annual_report_data)

writer = pd.ExcelWriter('exported_data.xlsx', engine='xlsxwriter')

df_q.to_excel(writer, sheet_name='BS - Quarterly Reports', index=False)
df_a.to_excel(writer, sheet_name='BS - Annual Reports', index=False)

# %%
# FROM INCOME STATEMENT:
q2 = income_statement_data['quarterlyReports']
df_q2 = pd.DataFrame(q2)
a2 = income_statement_data['annualReports']
df_a2 = pd.DataFrame(a2)

df_q2.to_excel(writer, sheet_name='IS - Quarterly Reports', index=False)
df_a2.to_excel(writer, sheet_name='IS - Annual Reports', index=False)

writer.save()
